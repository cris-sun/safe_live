# %% [markdown]
# # <center> Data enriching

# %% [markdown]
# - The goal of this notebook is to work on enriching the data.
# - The final output should be a new dataset (or a functions that generates the new dataset)

# %% [markdown]
# # Step 1 : Getting the base dataset

# %%
# !pip install geopandas

# %%
# Calculus
import pandas as pd

import os

# Data viz
import plotly.express as px
import plotly.io as pio
pio.renderers.default='notebook'

import geopandas as gpd
import folium
import pandas as pd
import branca.colormap as cm

# %%
# fetch all the data from the raw_data folder
current_dir = os.getcwd()
current_dir

file_path = os.path.join(current_dir, '..', 'raw_data', 'data.csv')
df = pd.read_csv(file_path)

# %% [markdown]
# # Filtering the columns to use

# %%
columns_keep = [
#'division_number',
'date_reported',
'date_occurred',
#'area',
'area_name',
#'reporting_district',
#'part',
#'crime_code',
'crime_description',
#'modus_operandi',
'victim_age',
'victim_sex',
'victim_descent',
#'premise_code',
'premise_description',
#'weapon_code',
'weapon_description',
#'status',
'status_description',
#'crime_code_1',
#'crime_code_2',
#'crime_code_3',
#'crime_code_4',
'location',
#'cross_street',
'latitude',
'longitude',
]

# %% [markdown]
# # Adding the dates infos

# %%
df = df[columns_keep]
df['counter']=1

# Dates
df['date_occurred'] = pd.to_datetime(df['date_occurred'], errors='coerce')
df['year_occurred'] = df['date_occurred'].dt.year
df['month_occurred'] = df['date_occurred'].dt.month
df['hour_occurred'] = df['date_occurred'].dt.hour

df.head(3)

# %%
# Load the shapefile

# fetch all the data from the raw_data folder

file_path = os.path.join(current_dir, '..', 'raw_data','geo_data','cfbcc20d-2c5d-4c30-9dfa-627d46ec1a742020328-1-9ulknm.pzqsm.shp')

neighborhoods = gpd.read_file(file_path)

# %%
# Convert DataFrame to GeoDataFrame
crime_data_gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitude, df.latitude))
crime_data_gdf.set_crs(neighborhoods.crs, inplace=True).head(1)

# %%
# Perform a spatial join
joined_gdf = gpd.sjoin(crime_data_gdf, neighborhoods, how='left', op='within')
joined_gdf.head(1)

# %% [markdown]
# # Now "name" replace "area_name" and as the neiborhood name

# %% [markdown]
# # Let's add a scoring per crimes types

# %%
crimes_df = pd.DataFrame(joined_gdf['crime_description'].unique())
crimes_df.columns=['crime_description']
crimes_df

# %%
# Assigning gravity scores based on the type of crime
# This is a subjective assignment and should ideally be based on more detailed criteria

def assign_gravity(crime_description):
    lower_case_description = crime_description.lower()
    if any(word in lower_case_description for word in ['petty theft', 'vandalism', 'minor fraud', 'trespass','stole']):
        return 1  # Low Gravity
    elif any(word in lower_case_description for word in ['burglary', 'serious fraud', 'aggravated assault', 'robbery']):
        return 2  # Medium Gravity
    elif any(word in lower_case_description for word in ['homicide', 'rape', 'kidnapping', 'arson','dead','penetration','penis','child pornography']):
        return 3  # High Gravity
    else:
        return 1  # Default to Low Gravity if not clearly fitting other categories

# Apply the gravity scoring function to the dataset
crimes_df['gravity_for_tourist'] = crimes_df['crime_description'].apply(assign_gravity)

crimes_df.head()

# %%
# Apply the gravity scoring function to the dataset
joined_gdf['gravity_for_tourist'] = crimes_df['crime_description'].apply(assign_gravity)

joined_gdf.head()

# %%
import sys
import os

# Path to the folder containing my_module.py
folder_path = os.path.abspath(os.path.join('..', 'library'))

# Add this path to sys.path
sys.path.insert(0, folder_path)

# Now you can import your module or functions
import la_functions as la

# %%
df_enriched = la.data_enriching('data.csv')
# Out:
# /home/antoine/.pyenv/versions/lewagon/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3378: FutureWarning:
#
# The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.

# %%
df_enriched
# Out:
#        date_reported       date_occurred    area_name  \
# 0         2020-01-08 2020-01-08 22:30:00    Southwest
# 1         2020-01-02 2020-01-01 03:30:00      Central
# 2         2020-04-14 2020-02-13 12:00:00      Central
# 3         2020-01-01 2020-01-01 17:30:00  N Hollywood
# 4         2020-01-01 2020-01-01 04:15:00      Mission
# ...              ...                 ...          ...
# 852945    2023-03-22 2023-03-22 10:00:00     Foothill
# 852946    2023-04-12 2023-04-12 16:30:00  77th Street
# 852947    2023-07-02 2023-07-01 00:01:00      Central
# 852948    2023-03-05 2023-03-05 09:00:00     Van Nuys
# 852949    2023-11-10 2023-11-09 23:00:00    Southwest
#
#                                         crime_description  victim_age  \
# 0                                BATTERY - SIMPLE ASSAULT          36
# 1                                BATTERY - SIMPLE ASSAULT          25
# 2               SEX OFFENDER REGISTRANT OUT OF COMPLIANCE           0
# 3                VANDALISM - MISDEAMEANOR ($399 OR UNDER)          76
# 4       VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...          31
# ...                                                   ...         ...
# 852945     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT          25
# 852946     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT          29
# 852947                                         PICKPOCKET          24
# 852948           VANDALISM - MISDEAMEANOR ($399 OR UNDER)          53
# 852949  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...          38
#
#        victim_sex victim_descent  \
# 0               F              B
# 1               M              H
# 2               X              X
# 3               F              W
# 4               X              X
# ...           ...            ...
# 852945          F              H
# 852946          M              B
# 852947          F              H
# 852948          F              H
# 852949          M              W
#
#                                  premise_description  \
# 0                             SINGLE FAMILY DWELLING
# 1                                           SIDEWALK
# 2                                    POLICE FACILITY
# 3       MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 4                                BEAUTY SUPPLY STORE
# ...                                              ...
# 852945                                      SIDEWALK
# 852946                                    LAUNDROMAT
# 852947               NIGHT CLUB (OPEN EVENINGS ONLY)
# 852948  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 852949                        SINGLE FAMILY DWELLING
#
#                                     weapon_description status_description  \
# 0       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)        Adult Other
# 1                          UNKNOWN WEAPON/OTHER WEAPON        Invest Cont
# 2                                                  NaN       Adult Arrest
# 3                                                  NaN        Invest Cont
# 4                                                  NaN        Invest Cont
# ...                                                ...                ...
# 852945  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)        Invest Cont
# 852946                     UNKNOWN WEAPON/OTHER WEAPON        Invest Cont
# 852947                                             NaN        Invest Cont
# 852948                                             NaN        Invest Cont
# 852949                                             NaN        Invest Cont
#
#         ... longitude  counter  year_occurred  month_occurred  hour_occurred  \
# 0       ... -118.2978        1           2020               1             22
# 1       ... -118.2545        1           2020               1              3
# 2       ... -118.2474        1           2020               2             12
# 3       ... -118.4019        1           2020               1             17
# 4       ... -118.4468        1           2020               1              4
# ...     ...       ...      ...            ...             ...            ...
# 852945  ... -118.4116        1           2023               3             10
# 852946  ... -118.2915        1           2023               4             16
# 852947  ... -118.2485        1           2023               7              0
# 852948  ... -118.4487        1           2023               3              9
# 852949  ... -118.3078        1           2023              11             23
#
#                            geometry  index_right OBJECTID             name  \
# 0       POINT (-118.29780 34.01410)         31.0     32.0  Exposition Park
# 1       POINT (-118.25450 34.04590)         23.0     24.0         Downtown
# 2       POINT (-118.24740 34.04480)         23.0     24.0         Downtown
# 3       POINT (-118.40190 34.16850)         95.0     96.0   Valley Village
# 4       POINT (-118.44680 34.21980)         71.0     72.0    Panorama City
# ...                             ...          ...      ...              ...
# 852945  POINT (-118.41160 34.27900)         69.0     70.0          Pacoima
# 852946  POINT (-118.29150 33.98410)         99.0    100.0  Vermont-Slauson
# 852947  POINT (-118.24850 34.04670)         23.0     24.0         Downtown
# 852948  POINT (-118.44870 34.19510)         96.0     97.0         Van Nuys
# 852949  POINT (-118.30780 34.00910)        100.0    101.0   Vermont Square
#
#         gravity_for_tourist
# 0                         1
# 1                         1
# 2                         1
# 3                         1
# 4                         1
# ...                     ...
# 852945                    2
# 852946                    2
# 852947                    1
# 852948                    1
# 852949                    1
#
# [854786 rows x 22 columns]

# %% [markdown]
# prompt asked to chat gpt:
#
# User
# Here is a series of crimes. I want you to had a column "gravity" and a column "probability to happen to a toursit" and grade the proba from 0 to 1 and the gravity from 1 to 3 with 1 being low and high biing 3
